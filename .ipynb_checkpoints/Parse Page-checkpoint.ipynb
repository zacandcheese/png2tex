# %%
import numpy as np
from PIL import Image as im
from PIL import ImageOps as imo
from numpy.lib.stride_tricks import sliding_window_view

# %%
name = "z"
figure_img = im.open(f"imgs/macro_images/{name}.JPG")
figure_img = imo.grayscale(figure_img)
#figure_img = figure_img.resize((640,320), resample=im.NEAREST)
figure_img = figure_img.rotate(270, expand=True)
figure = np.asarray(figure_img) / 255
img = im.fromarray(np.uint8(figure * 255), 'L')

# All Edges
pixels = sliding_window_view(figure, (3,3))
number_of_pixels = pixels.shape[0] * pixels.shape[1]
shape = (pixels.shape[0], pixels.shape[1])
white = np.reshape(pixels, (number_of_pixels,9)).max(axis=-1).reshape(shape)
edges = np.pad(white, pad_width=1, mode='constant')
np.subtract(edges,figure,out=edges)
np.greater_equal(edges, 0.04, out=edges) # contrast
img = im.fromarray(np.uint8(edges * 255), 'L')
display(img)

# Critical Edges
pixels = sliding_window_view(figure, (3,3))
number_of_pixels = pixels.shape[0] * pixels.shape[1]
shape = (pixels.shape[0], pixels.shape[1])
white = np.reshape(pixels, (number_of_pixels,9)).max(axis=-1).reshape(shape)
crit_edges = np.pad(white, pad_width=1, mode='constant')
np.subtract(crit_edges,figure,out=crit_edges)
np.greater_equal(crit_edges, 0.2, out=crit_edges) # contrast
img = im.fromarray(np.uint8(crit_edges * 255), 'L')
display(img)
# Out:
# <PIL.Image.Image image mode=L size=2448x3264 at 0x7F48F1F06090>
# <PIL.Image.Image image mode=L size=2448x3264 at 0x7F48F1F6B850>

# %%
# BLUR
n = 3 #odd number
pixels = sliding_window_view(edges, (n,n))
number_of_pixels = pixels.shape[0] * pixels.shape[1]
shape = (pixels.shape[0], pixels.shape[1])
blur = np.reshape(pixels, (number_of_pixels,n**2)).max(axis=-1).reshape(shape)
blur = np.pad(blur, pad_width=1, mode='constant')
img = im.fromarray(np.uint8(blur * 255), 'L')
display(img)

# Critical Edges
pixels = sliding_window_view(blur, (3,3))
number_of_pixels = pixels.shape[0] * pixels.shape[1]
shape = (pixels.shape[0], pixels.shape[1])
white = np.reshape(pixels, (number_of_pixels,9)).max(axis=-1).reshape(shape)
blur_edges = np.pad(white, pad_width=1, mode='constant')
np.subtract(blur_edges,blur,out=blur_edges)
np.greater_equal(blur_edges, 0.01, out=blur_edges) # contrast
img = im.fromarray(np.uint8(blur_edges * 255), 'L')
display(img)
print(np.count_nonzero(blur == 1))
print(np.count_nonzero(blur_edges == 1))
# Out:
# <PIL.Image.Image image mode=L size=2448x3264 at 0x7F48F1F6B5D0>
# <PIL.Image.Image image mode=L size=2448x3264 at 0x7F48F1F6B7D0>
# 132227
# 74749

# %%
def rot(old_coord):
    # Input: Last relative coordinate
    # Output: Next relative coordinate
    last = old_coord
    if   (last == (-1,-1)):
        return    (-1, 0)
    elif (last == (-1, 0)):
        return    (-1, 1)
    elif (last == (-1, 1)):
        return    (0, 1)
    elif (last == (0, 1)):
        return    (1, 1)
    elif (last == (1, 1)):
        return    (1, 0)
    elif (last == (1, 0)):
        return    (1, -1)
    elif (last == (1, -1)):
        return    (0, -1)
    else:
        return    (-1, -1)

# %%
def next_coord(coord, edges, last_coord):
    # Input: x,y coordinate of current pixel
    #        set of all edges
    #        last pixel seen
    # Output: next pixel in clockwise order
    (y,x) = coord
    (last_y, last_x) = last_coord
    rel_coord = (last_y - y, last_x - x)
    for _ in range(8): # Was 7
        (diff_y, diff_x) = rot(rel_coord)
        if (tuple([y + diff_y, x + diff_x]) in edges): #true if an edge
            return (y + diff_y, x + diff_x)
        rel_coord = (diff_y, diff_x)
    return None

# %%
def outline(start, edges):
    # Input: start edge, possible connecting edges
    # Output of the pixels on the border of image
    # in clockwise order
    (y,x) = start
    last = (0,0)
    (offset_y, offset_x) = (1, 0)
    last = (y+offset_y, x+offset_x)
    
    #ToDO Find the side that has white on it
        
    next_ = next_coord(start, edges, last) # wrong
    # better way to correct for next_
    
    
    last = start
    border = [start]
    border_set = set(start)
    while(True):
        if (next_ == None or next_ == start):#or next_ in border_set):
            break
        else:
            border.append(next_)
            border_set.add(next_)
            new_next = next_coord(next_, edges, last)
            last = next_
            next_ = new_next
    #print(border)      
    return border

# %%
def plot_borders(borders, size):
    print(size)
    temp = np.zeros(shape=size)
    for border in borders:
        for (y,x) in border:
            temp[y,x] = 255

    temp = temp.astype(np.uint8)
    img = im.fromarray(temp)
    display(img)

# %%
def plot_border(border, size):
    print(size)
    y_min = min(border)[0]
    x_min = min(border, key=lambda x:x[1])[1]
    temp = np.zeros(shape=size)
    for (y,x) in border:
        temp[y-y_min,x-x_min] = 255

    temp = temp.astype(np.uint8)
    img = im.fromarray(temp)
    display(img)
    return temp

# %%
ii = np.where(crit_edges == 1)
crit_points = set(tuple(zip(*ii)))
ii = np.where(blur_edges == 1)
points = set(tuple(zip(*ii)))

print(len(crit_points))
print(len(points))
print(len(crit_points - points))
# NOTE ALL crit_points are in points
# Out:
# 18128
# 74749
# 18128

# %%
# Move all crit_points up until they are in points
new = set()
while(len(crit_points) != 0):
    start = crit_points.pop()
    while(start not in points and start[0] > 0):
        start = (start[0]-1, start[1])
    if (start[0] > 0):
        new.add(start)
    
crit_points = new
print(len(crit_points))
print(len(points))
print(len(crit_points - points))
# Out:
# 7681
# 74749
# 0

# %%
borders = []
while(len(crit_points) != 0): #!=
    start_edge_point = crit_points.pop()
    border = outline(start_edge_point, points)
    if (1000 > len(border) > 250): # >250
        borders.append(border)
    temp = set(border)
    if ((1600, 1796) in temp):
        print("ERROR--", start_edge_point)
    points = points - temp
    crit_points = crit_points - temp
    
print(len(borders))
plot_borders(borders, crit_edges.shape)
# Out:
# 36
# (3264, 2448)
# <PIL.Image.Image image mode=L size=2448x3264 at 0x7F493C281F50>

# %%
temp = list(map(lambda x: len(x), borders))
temp.sort()
print(temp)
# Out:
# [502, 546, 559, 573, 580, 596, 608, 618, 631, 635, 640, 641, 655, 656, 660, 660, 660, 661, 666, 667, 667, 668, 674, 675, 676, 677, 685, 691, 692, 692, 704, 707, 726, 732, 765, 808]

# %%
import random
idx = random.randint(0, len(borders)-1)
#idx = 52

# %%
z = 5 #z for zoom
left_x = min(borders[idx])[0]
right_x = max(borders[idx])[0]
left_y = min(borders[idx], key=lambda t: t[1])[1]
right_y = max(borders[idx], key=lambda t:t[1])[1]
print(left_x, right_x, left_y, right_y)
print("start: ",borders[idx][0], "end: ",borders[idx][-1] )
print(len(borders[idx]), len(set(borders[idx])))
temp = plot_border(borders[idx], (right_x - left_x + 1, right_y - left_y + 1))
#FIXME: vvv
#temp = figure[left_x:right_x, left_y: right_y]
#img = im.fromarray(np.uint8(temp*255), 'L')
#display(img)
#END FIXME:
img = im.fromarray(np.uint8(blur_edges[left_x-z:right_x+z, left_y-z:right_y+z] * 255), 'L')
display(img)
#plot_borders([borders[idx]], crit_edges.shape)
idx = idx + 1
print(idx)
# Out:
# 565 670 874 1031
# start:  (658, 1010) end:  (658, 1011)
# 674 671
# (106, 158)
# <PIL.Image.Image image mode=L size=158x106 at 0x7F48E8016D90>
# <PIL.Image.Image image mode=L size=167x115 at 0x7F48E8016F10>
# 10

# %%
whats_left = np.array([0 for _ in range(len(borders))])

# %%
import concave_hull
amt = len(borders[idx-1]) // 64
j = 1

grounds = []
for j in range(len(borders)):
    others = []
    for other in range(len(borders)):
        res2 = concave_hull.convert_border(borders[other])
        direct_comp = []
        for turn in range(3):
            temp = borders[j][turn*amt:]
            temp.extend(borders[j][:turn*amt])
            res1 = concave_hull.convert_border(temp)
            for i in range(0,16):
                temp = res1[i:]# + res[:i]
                temp.extend(res1[:i])
                t1 = np.array([x[0] for x in res2])
                t2 = np.array([x[0] for x in temp])

                d1 = np.array([x[1] for x in res2])
                d2 = np.array([x[1] for x in temp])

                val = sum(t1 - t2) + sum(d1 - d2)
                direct_comp.append(val)
        others.append(min(direct_comp))
    
    matches = np.array(list(map(lambda x: 1 if x < 15 else 0, others)))
    #print(sum(matches), len(matches), "\n", others, "\n", matches)
    print(sum(matches))
    grounds.append(matches)
# Out:
# 20
# 30
# 33
# 33
# 31
# 29
# 34
# 26
# 26
# 32
# 32
# 33
# 34
# 33
# 33
# 34
# 32
# 16
# 26
# 31
# 31
# 35
# 32
# 33
# 15
# 2
# 30
# 34
# 30
# 32
# 33
# 33
# 29
# 30
# 31
# 29

# %%
best = 0
best_tuple = (0,0,0)
for i,a in enumerate(grounds):
    for j,b in enumerate(grounds):
        for k,c in enumerate(grounds):
            whats_left = np.array([0 for _ in range(len(borders))])
            np.bitwise_or(whats_left, a, out=whats_left)
            np.bitwise_or(whats_left, b, out=whats_left)
            np.bitwise_or(whats_left, c, out=whats_left)
            total = np.sum(whats_left)
            if(total > best):
                best = total
                best_tuple = (i, j, k)
                
print(best, best_tuple, len(borders))
# Out:
# 36 (0, 1, 25) 36

# %%
#import hu_moment
#import math
#arr = hu_moment.hu(temp)
#arr = list(map(lambda x: math.log(abs(x)), arr))

# %%
#import csv
#with open('shapes.csv', 'a', encoding='UTF8') as f:
#    writer = csv.writer(f)
#    arr.insert(0, name)
#    writer.writerow(arr)
#    f.close()

# %%
# # # THIS ONE CONTROLS CSV UPLOAD
# import csv
# import concave_hull

# j = 25
# with open('shapes_border_16.csv', 'a', encoding='UTF8') as f:
#     amt = len(borders[j]) // 64
#     writer = csv.writer(f)
#     for turn in range(3):
#         temp = borders[j][turn*amt:]
#         temp.extend(borders[j][:turn*amt])
#         res = concave_hull.convert_border(temp)
#         arr = list(map(lambda x: [x[0].cur.value, x[1].dir.value], res))
#         arr = [item for sublist in arr for item in sublist]
#         arr.insert(0, name)
#         writer.writerow(arr)
#     f.close()

# %%
#import concave_hull
#from concave_hull import Cardinal, Curvage, Geometry

#Cardinal['N']
#res = concave_hull.convert_border(borders[idx])
#temp = list(map(lambda x: [x[0].cur.value, x[1].dir.value], res))
#temp = [item for sublist in temp for item in sublist]
#print(temp)

#rep = [(Curvage(temp[2*i]), Cardinal(temp[2*i+1])) for i in range(len(temp)//2)]
#rep[0][0] - rep[1][0]

# %%
#arr = np.array(arr).astype(float)
#with open('shapes.csv', newline='') as f:
#    spamreader = csv.reader(f, delimiter=',')
#    all_scores = []
#    for row in spamreader:
#        known_arr = np.array(list(map(lambda x: float(x), row[1:]))).astype(float)
#        #score = np.sum(np.abs(arr - known_arr))
#        #score = np.linalg.norm(arr - known_arr)
#        #score = np.sum(np.abs(np.reciprocal(arr) - np.reciprocal(known_arr)))
#        if (row[0] == 'a'):
#            print(arr, "\n", known_arr, "\n", score)
#        all_scores.append(tuple([score, row[0]]))
#    all_scores.sort()
#    print(all_scores[0:5])
#    f.close()

# %%
import csv
import concave_hull
from concave_hull import Cardinal, Curvage, Geometry

res = concave_hull.convert_border(borders[idx-1])
arr = list(map(lambda x: (x[0].cur, x[1].dir), res))
all_scores = []
with open('shapes_border_16.csv', newline='') as f:
    spamreader = csv.reader(f, delimiter=',')
    all_scores = []
    for row in spamreader:
        temp = np.array(row[1:]).astype(int) #get rid of the letter
        known = [(Curvage(temp[2*i]), Cardinal(temp[2*i+1])) for i in range(len(temp)//2)]
        
        scores = []
        for i in range(0,12):
            rot = arr[i:]# + res[:i]
            rot.extend(arr[:i])
    
            t1 = np.array([x[0] for x in known])
            t2 = np.array([x[0] for x in rot])
    
            d1 = np.array([x[1] for x in known])
            d2 = np.array([x[1] for x in rot])
            scores.append(sum(t1 - t2) + sum(d1 - d2))
            
        score = min(scores)
        all_scores.append(tuple([score, row[0]]))
    all_scores.sort()
    print(all_scores[0:5])
    f.close()
# Out:
# [(6, 'z'), (10, 'z'), (12, 'z'), (16, 'z'), (18, 'z')]
